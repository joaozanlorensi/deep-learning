# %%
'''Trains a simple deep NN on the MNIST dataset.
Gets to 98.40% test accuracy after 20 epochs
(there is *a lot* of margin for parameter tuning).
2 seconds per epoch on a K520 GPU.
'''

from __future__ import print_function

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.utils import np_utils
from tensorflow.keras.optimizers import RMSprop


batch_size = 128
num_classes = 10
epochs = 20

# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
y_test = keras.utils.np_utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(784,)))
model.add(Dense(10, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2921 - accuracy: 0.9184 - val_loss: 0.1630 - val_accuracy: 0.9511
# Epoch 2/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1273 - accuracy: 0.9628 - val_loss: 0.1078 - val_accuracy: 0.9670
# Epoch 3/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0861 - accuracy: 0.9750 - val_loss: 0.0828 - val_accuracy: 0.9745
# Epoch 4/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0648 - accuracy: 0.9812 - val_loss: 0.0774 - val_accuracy: 0.9763
# Epoch 5/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0503 - accuracy: 0.9851 - val_loss: 0.0757 - val_accuracy: 0.9782
# Epoch 6/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0406 - accuracy: 0.9880 - val_loss: 0.0688 - val_accuracy: 0.9800
# Epoch 7/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0330 - accuracy: 0.9905 - val_loss: 0.0716 - val_accuracy: 0.9792
# Epoch 8/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0264 - accuracy: 0.9926 - val_loss: 0.0762 - val_accuracy: 0.9796
# Epoch 9/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0220 - accuracy: 0.9938 - val_loss: 0.0675 - val_accuracy: 0.9801
# Epoch 10/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0179 - accuracy: 0.9954 - val_loss: 0.0703 - val_accuracy: 0.9800
# Epoch 11/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0144 - accuracy: 0.9961 - val_loss: 0.0705 - val_accuracy: 0.9811
# Epoch 12/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0116 - accuracy: 0.9969 - val_loss: 0.0770 - val_accuracy: 0.9807
# Epoch 13/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0098 - accuracy: 0.9974 - val_loss: 0.0762 - val_accuracy: 0.9812
# Epoch 14/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0081 - accuracy: 0.9980 - val_loss: 0.0706 - val_accuracy: 0.9826
# Epoch 15/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0064 - accuracy: 0.9986 - val_loss: 0.0783 - val_accuracy: 0.9818
# Epoch 16/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.0828 - val_accuracy: 0.9811
# Epoch 17/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.0828 - val_accuracy: 0.9803
# Epoch 18/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.0860 - val_accuracy: 0.9803
# Epoch 19/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.0890 - val_accuracy: 0.9812
# Epoch 20/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0905 - val_accuracy: 0.9808
# Test loss: 0.09048900753259659
# Test accuracy: 0.9807999730110168
